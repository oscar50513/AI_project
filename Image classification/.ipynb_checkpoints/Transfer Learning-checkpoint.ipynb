# %%
# https://keras.io/api/applications/

# %%
import os 
import numpy as np
import cv2

# %%
path_good = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\good_cut"
path_bad  = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\insect damaged bean"
h,w=224,224

good_num = len(os.listdir (path_good))
insect_num = len(os.listdir (path_bad))
total = good_num + insect_num
x_train_image = np.empty((total,h,w,3),dtype=np.uint8)
y_train_label = np.empty((total),dtype=np.uint8)
c = 0
for idx,name in enumerate(os.listdir(path_good)):
    c+=1
    img = cv2.imread(os.path.join(path_good,name))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img,(w,h))
    x_train_image[idx] = img
    y_train_label[idx] = 0
print('good_num:',c)
c = 0
for idx,name in enumerate(os.listdir(path_bad)):
    c+=1
    img = cv2.imread(os.path.join(path_bad,name))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img,(w,h))
    x_train_image[good_num+idx] = img
    y_train_label[good_num+idx] = 1
print('insect_num:',c)
print('total:', total)
# Out:
# good_num: 2512
# insect_num: 2244
# total: 4746

# %%
cv2.imshow('test',x_train_image[212])
cv2.waitKey()
cv2.destroyAllWindows()

# %%
x_train_image.shape
# Out:
# (4746, 224, 224, 3)

# %%
y_train_label.shape
# Out:
# (4746,)

# %%
import matplotlib.pyplot as plt
label = {1:'insect',0:'good'}
plt.figure(figsize=(15,10))
for i in range(15):
    ax = plt.subplot(3, 5, 1+i)
    #ax.set_title("Label: %s" %(y_val_label[i]), size=20)
    ax.set_title("Label: %s" %label[y_train_label[i*15]], size=20)
    ax.imshow(x_train_image[i*15])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train_image, x_test_image, y_train_label, y_test_label = train_test_split(x_train_image, y_train_label, test_size=0.2, random_state=42)
from collections import Counter
print("訓練集的類別數量：%s" %Counter(y_train_label))
print("訓練集的維度：", x_train_image.shape)
print("測試集的類別數量：%s" %Counter(y_test_label))
print("測試集的維度：", x_test_image.shape)
# Out:
# 訓練集的類別數量：Counter({0: 2003, 1: 1793})
# 訓練集的維度： (3796, 224, 224, 3)
# 測試集的類別數量：Counter({0: 499, 1: 451})
# 測試集的維度： (950, 224, 224, 3)

# %%
from tensorflow.keras.utils import to_categorical
import numpy as np

y_train = to_categorical(y_train_label)
y_val = to_categorical(y_test_label)

x_train = x_train_image.astype('float32')/255
x_val = x_test_image.astype('float32')/255

# %%
# Keras中的模型應用(使用遷移式學習) (以InceptionV3為例)
import tensorflow.keras.applications as keras_model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
base_model = keras_model.ResNet50V2(include_top=False, weights="imagenet",
                                input_shape=(224, 224, 3), pooling=None, classes=2)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation="relu")(x)
x = Dense(512, activation="relu")(x)
output = Dense(2, activation="softmax")(x)
model = Model(inputs=base_model.input, outputs=output)
model.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_5[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
# ...

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer = Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['acc'])

from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
# 可視化訓練過程
tensorboard = TensorBoard(log_dir="my_log")
# 模型檢查點
model_checkpoint = ModelCheckpoint(filepath="weight.{epoch:02d}-{val_acc:.4f}.h5",
                                   monitor="val_acc", save_best_only=True, verbose=0)

history = model.fit(x=x_train, y=y_train, batch_size=32, epochs=10, verbose=1, shuffle=True,validation_data=(x_val, y_val)
                    ,callbacks=[tensorboard, model_checkpoint])
# Out:
# Epoch 1/10
# 119/119 [==============================] - 19s 135ms/step - loss: 0.1211 - acc: 0.9473 - val_loss: 0.0399 - val_acc: 0.9863
# Epoch 2/10
# 119/119 [==============================] - 14s 116ms/step - loss: 0.0325 - acc: 0.9887 - val_loss: 0.0150 - val_acc: 0.9916
# Epoch 3/10
# 119/119 [==============================] - 13s 112ms/step - loss: 0.0149 - acc: 0.9958 - val_loss: 0.0266 - val_acc: 0.9916
# Epoch 4/10
# 119/119 [==============================] - 14s 117ms/step - loss: 0.0104 - acc: 0.9966 - val_loss: 0.0100 - val_acc: 0.9958
# Epoch 5/10
# 119/119 [==============================] - 13s 112ms/step - loss: 0.0191 - acc: 0.9958 - val_loss: 0.0846 - val_acc: 0.9779
# Epoch 6/10
# 119/119 [==============================] - 13s 111ms/step - loss: 0.0276 - acc: 0.9918 - val_loss: 0.0722 - val_acc: 0.9811
# Epoch 7/10
# 119/119 [==============================] - 13s 111ms/step - loss: 0.0099 - acc: 0.9966 - val_loss: 0.0147 - val_acc: 0.9958
# Epoch 8/10
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir=my_log
# Out:
#       <iframe id="tensorboard-frame-11682048eb2b67fa" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-11682048eb2b67fa");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# 繪製訓練過程
import matplotlib.pyplot as plt
import numpy as np
acc = history.history['acc'];
loss = history.history['loss']
val_acc = history.history['val_acc'];
val_loss = history.history['val_loss']
plt.title("Learning Curve - Acc", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Accuracy", fontsize=18)
plt.plot(np.arange(len(acc)), acc,color='b', label="Training set")
plt.plot(np.arange(len(val_acc)), val_acc,color='r', label="Val set")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right',fontsize=14)
plt.show()

plt.title("Learning Curve - Loss", fontsize=20)
plt.xlabel("Epoch", fontsize=18)
plt.ylabel("Accuracy", fontsize=18)
plt.plot(np.arange(len(loss)), loss,color='b', label="Training set")
plt.plot(np.arange(len(val_loss)), val_loss,color='r', label="Val set")
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right',fontsize=14)
plt.show()

# %%
import os
path = os.getcwd()
n = os.listdir(path)
name = [i for i in n if '.h5' in i]
name[-1]
# Out:
# 'weight.08-0.9979.h5'

# %%
from tensorflow.keras.models import load_model
import os
path = os.getcwd()
n = os.listdir(path)
name = [i for i in n if '.h5' in i]
model = load_model(name[-1])

with tf.device('/cpu:0'):
    val_predict = model.predict(x_val)
from sklearn.metrics import confusion_matrix

val_predictions = [np.argmax(i) for i in val_predict]
val_cm = confusion_matrix(y_test_label, val_predictions)
print(val_cm)
# Out:
# [[499   0]
#  [  2 449]]

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
plt.title('val set', size = 20)
sns.heatmap(val_cm, annot=True, fmt=".0f", linewidths=1.0,
            square = True, cmap = "Oranges", annot_kws={"size":16})
plt.xlabel('Predicted label', size = 18)
plt.ylabel('Actual label', size = 18)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.show()

# %%
train_loss, train_acc = model.evaluate(x_train, y_train)
print("訓練集的準確度:%0.4f" %(train_acc))
print("訓練集的損失值:%0.4f" %(train_loss))
val_loss, val_acc = model.evaluate(x_val, y_val)
print("驗證集的準確度:%0.4f" %(val_acc))
print("驗證集的損失值:%0.4f" %(val_loss))
# Out:
# 119/119 [==============================] - 5s 35ms/step - loss: 0.0010 - acc: 0.9995
# 訓練集的準確度:0.9995
# 訓練集的損失值:0.0010
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0057 - acc: 0.9979
# 驗證集的準確度:0.9979
# 驗證集的損失值:0.0057

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test_label, val_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       499
#            1       1.00      1.00      1.00       451
#
#     accuracy                           1.00       950
#    macro avg       1.00      1.00      1.00       950
# weighted avg       1.00      1.00      1.00       950

# %%
Accuracy=(val_cm[0][0]+val_cm[1][1])/(val_cm[0][0]+val_cm[0][1]+val_cm[1][0]+val_cm[1][1])
Recall=val_cm[1][1]/(val_cm[1][0]+val_cm[1][1])
Specificity=val_cm[0][0]/(val_cm[0][0]+val_cm[0][1])

print("準確度: %f" %(Accuracy))
print("敏感度: %f" %(Recall))
print("特異度: %f" %(Specificity))
# Out:
# 準確度: 0.997895
# 敏感度: 0.995565
# 特異度: 1.000000

# %%
import cv2
img = cv2.imread(r"C:\Users\Landis\Desktop\yolov7-main\coffee bean\insect damaged bean\w_55.jpg")
x=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
x= cv2.resize(x,(w,h))
x = np.expand_dims(x, axis=0)
x=x.astype("float32")/255
preds = model.predict(x)
print(preds)
pred=label[np.argmax(preds)]
print(pred)
img2 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.title('test')
plt.imshow(img2)
plt.show()
# Out:
# [[2.101053e-05 9.999790e-01]]
# insect

# %%
# Grad-CAM CNN視覺化
from tensorflow.keras import models
from tensorflow.keras import backend as K
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
img = cv2.imread(r"C:\Users\Landis\Desktop\yolov7-main\coffee bean\insect damaged bean\w_55.jpg")
x=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
x= cv2.resize(x,(w,h))
x = np.expand_dims(x, axis=0)
x=x.astype("float32")/255

conv_layer = model.get_layer("conv5_block1_1_conv") # 將要觀察的卷積層取出
heatmap_model = models.Model([model.inputs], [conv_layer.output, model.output]) #建立「輸入層」至「觀察之卷積層」的模型

with tf.GradientTape() as gtape:                         # tf.GradientTape可監控與計算梯度
    conv_output, predictions = heatmap_model(x)
    prob = predictions[:, np.argmax(predictions[0])]     # 取機率最大的類別之機率
    grads = gtape.gradient(prob, conv_output)            # 計算類別與卷積層的梯度
    pooled_grads = K.mean(grads, axis=(0, 1, 2))         # 平均每層權重
heatmap = tf.reduce_mean(tf.multiply(pooled_grads, conv_output), axis=-1) # 權重與特徵圖相乘，並求和平均
heatmap = np.maximum(heatmap, 0)      
heatmap /= np.max(heatmap)
heatmap = heatmap[0]
plt.imshow(heatmap)
plt.show()

# %%
import cv2
def add_heatmap(heatmap, image, alpha=0.8, colormap=cv2.COLORMAP_VIRIDIS):
    heatmap = cv2.applyColorMap(heatmap, colormap)
    output = cv2.addWeighted(image, alpha, heatmap, 1 - alpha, 0)
    return output

img = cv2.imread(r"C:\Users\Landis\Desktop\yolov7-main\coffee bean\insect damaged bean\w_55.jpg")
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap = np.uint8(255*heatmap)
output = add_heatmap(heatmap, img, alpha=0.5)
output = cv2.cvtColor(output, cv2.COLOR_BGR2RGB)
plt.imshow(output)
plt.show()
