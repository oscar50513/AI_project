# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix
import os,cv2
from tensorflow.keras.utils import to_categorical
import numpy as np

# insect
n = "insect bean"
path_fungus  = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\DataSet" + '\\' + n
path_dataset = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\DataSet"
path_not_bad = [i for i in os.listdir(path_dataset) if n not in i]
data_num = []
for dir_n in path_not_bad:
    num = len(os.listdir(path_dataset + '/' + dir_n))
    data_num.append(num)
total = sum(data_num)
fungus_num = len(os.listdir (path_fungus))
total += fungus_num
h,w=224,224
x_train_image = np.empty((total,h,w,3),dtype=np.uint8)
y_train_label = np.empty((total),dtype=np.uint8)
c = 0
temp = 0
for dir_name in path_not_bad:
    path_dir = os.path.join(path_dataset,dir_name)
    for idx,name in enumerate(os.listdir (path_dir)):
        c+=1
        img = cv2.imread(os.path.join(path_dir,name))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,(w,h))
        x_train_image[temp+idx] = img
        y_train_label[temp+idx] = 0
    temp += len(os.listdir (path_dir))
for idx,name in enumerate(os.listdir (path_fungus)):
    c+=1
    img = cv2.imread(os.path.join(path_fungus,name))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img,(w,h))
    x_train_image[temp+idx] = img
    y_train_label[temp+idx] = 1
label = {1:'insect',0:'not insect'}
from sklearn.model_selection import train_test_split
x_train_image, x_test_image, y_train_label1, y_test_label1 = train_test_split(x_train_image, y_train_label, test_size=0.2, random_state=42)
y_train = to_categorical(y_train_label1)
y_val = to_categorical(y_test_label1)
x_train = x_train_image.astype('float32')/255
x_val = x_test_image.astype('float32')/255
model_use = load_model(r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\Model_Insect\DenseNet201\weight.05-0.9955.h5")
val_predict = model_use.predict(x_val)
val_predictions1 = [np.argmax(i) for i in val_predict]

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix
import os,cv2
from tensorflow.keras.utils import to_categorical
import numpy as np

# insect
n = "broken bean"
path_fungus  = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\DataSet" + '\\' + n
path_dataset = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\DataSet"
path_not_bad = [i for i in os.listdir(path_dataset) if n not in i]
data_num = []
for dir_n in path_not_bad:
    num = len(os.listdir(path_dataset + '/' + dir_n))
    data_num.append(num)
total = sum(data_num)
fungus_num = len(os.listdir (path_fungus))
total += fungus_num
h,w=224,224
x_train_image = np.empty((total,h,w,3),dtype=np.uint8)
y_train_label = np.empty((total),dtype=np.uint8)
c = 0
temp = 0
for dir_name in path_not_bad:
    path_dir = os.path.join(path_dataset,dir_name)
    for idx,name in enumerate(os.listdir (path_dir)):
        c+=1
        img = cv2.imread(os.path.join(path_dir,name))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,(w,h))
        x_train_image[temp+idx] = img
        y_train_label[temp+idx] = 0
    temp += len(os.listdir (path_dir))
for idx,name in enumerate(os.listdir (path_fungus)):
    c+=1
    img = cv2.imread(os.path.join(path_fungus,name))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img,(w,h))
    x_train_image[temp+idx] = img
    y_train_label[temp+idx] = 1
label = {1:'borken',0:'not borken'}
from sklearn.model_selection import train_test_split
x_train_image, x_test_image, y_train_label, y_test_label2 = train_test_split(x_train_image, y_train_label, test_size=0.2, random_state=42)
y_train = to_categorical(y_train_label)
y_val = to_categorical(y_test_label2)
x_train = x_train_image.astype('float32')/255
x_val = x_test_image.astype('float32')/255
model_use = load_model(r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\Model_Broken\DenseNet201\weight.05-0.9989.h5")
val_predict = model_use.predict(x_val)
val_predictions2 = [np.argmax(i) for i in val_predict]

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix
import os,cv2
from tensorflow.keras.utils import to_categorical
import numpy as np

# insect
n = "fungus bean"
path_fungus  = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\DataSet" + '\\' + n
path_dataset = r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\DataSet"
path_not_bad = [i for i in os.listdir(path_dataset) if n not in i]
data_num = []
for dir_n in path_not_bad:
    num = len(os.listdir(path_dataset + '/' + dir_n))
    data_num.append(num)
total = sum(data_num)
fungus_num = len(os.listdir (path_fungus))
total += fungus_num
h,w=224,224
x_train_image = np.empty((total,h,w,3),dtype=np.uint8)
y_train_label = np.empty((total),dtype=np.uint8)
c = 0
temp = 0
for dir_name in path_not_bad:
    path_dir = os.path.join(path_dataset,dir_name)
    for idx,name in enumerate(os.listdir (path_dir)):
        c+=1
        img = cv2.imread(os.path.join(path_dir,name))
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,(w,h))
        x_train_image[temp+idx] = img
        y_train_label[temp+idx] = 0
    temp += len(os.listdir (path_dir))
for idx,name in enumerate(os.listdir (path_fungus)):
    c+=1
    img = cv2.imread(os.path.join(path_fungus,name))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img = cv2.resize(img,(w,h))
    x_train_image[temp+idx] = img
    y_train_label[temp+idx] = 1
label = {1:'fungus',0:'not fungus'}
from sklearn.model_selection import train_test_split
x_train_image, x_test_image, y_train_label3, y_test_label3 = train_test_split(x_train_image, y_train_label, test_size=0.2, random_state=42)
y_train = to_categorical(y_train_label3)
y_val = to_categorical(y_test_label3)
x_train = x_train_image.astype('float32')/255
x_val = x_test_image.astype('float32')/255
model_use = load_model(r"C:\Users\Landis\Documents\GitHub\AI_project\Image classification\\Model_Fungus\DenseNet201\weight.10-0.9898.h5")
val_predict = model_use.predict(x_val)
val_predictions3 = [np.argmax(i) for i in val_predict]

# %%
from sklearn.metrics import roc_curve, roc_auc_score, auc
import matplotlib.pyplot as plt
fpr, tpr, threshold = roc_curve(y_test_label1, val_predictions1)
fpr2, tpr2, threshold2 = roc_curve(y_test_label2, val_predictions2)
fpr3, tpr3, threshold3 = roc_curve(y_test_label3, val_predictions3)
print(fpr, tpr, threshold)
print(fpr2, tpr2, threshold2)
print(fpr3, tpr3, threshold3)

auc1 = auc(fpr, tpr)*100
auc2 = auc(fpr2, tpr2)*100
auc3 = auc(fpr3, tpr3)*100
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, color = 'orange', label = 'ROC curve of insect-infested (AUC = %0.3f%%)' % auc1)
plt.plot(fpr2, tpr2, color = 'red', label = 'ROC curve of broken             (AUC = %0.3f%%)' % auc2)
plt.plot(fpr3, tpr3, color = 'green', label = 'ROC curve of moldy              (AUC = %0.3f%%)' % auc3)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# [0.        0.0041841 1.       ] [0.         0.99390244 1.        ] [2 1 0]
# [0. 0. 1.] [0.         0.99615385 1.        ] [2 1 0]
# [0.         0.01071975 1.        ] [0.         0.99122807 1.        ] [2 1 0]

# %%
#繪製PR曲線

#繪製ROC曲線
fpr, tpr, threshold = roc_curve(y_test_label1, val_predictions1)
fpr2, tpr2, threshold2 = roc_curve(y_test_label2, val_predictions2)
fpr3, tpr3, threshold3 = roc_curve(y_test_label3, val_predictions3)
auc1 = auc(fpr, tpr)*100
auc2 = auc(fpr2, tpr2)*100
auc3 = auc(fpr3, tpr3)*100

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='orange', label='%s (Auc = %0.3f%%)' % ('ROC curve of insect-infested', auc1))
plt.plot(fpr2, tpr2, color='r', label='%s              (Auc = %0.3f%%)' % ('ROC curve of broken', auc2))
plt.plot(fpr3, tpr3, color='green', label='%s               (Auc = %0.3f%%)' % ('ROC curve of moldy', auc3))
plt.legend(loc='lower left')
plt.title("ROC Curve", size = 22)
plt.plot([0, 1],[0, 1], linestyle='--', color='gray', linewidth=2)
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.grid()
plt.xlabel('False Positive Rate', size = 20)
plt.ylabel('True Positive Rate', size = 20)
plt.show()


from sklearn.metrics import roc_curve, precision_recall_curve, auc
precision1, recall1, thresholds1 = precision_recall_curve(y_test_label1, val_predictions1)
precision2, recall2, thresholds2 = precision_recall_curve(y_test_label2, val_predictions2)
precision3, recall3, thresholds3 = precision_recall_curve(y_test_label3, val_predictions3)
pr_auc1 = auc(recall1, precision1)*100
pr_auc2 = auc(recall2, precision2)*100
pr_auc3 = auc(recall3, precision3)*100
plt.figure(figsize=(6,5))
plt.plot(recall1,precision1,color='orange',label='%s  (Auc = %0.3f%%)' % ('PR curve of insect-infested', pr_auc1))
plt.plot(recall2,precision2,color='r',label='%s              (Auc = %0.3f%%)' % ('PR curve of broken', pr_auc2))
plt.plot(recall3,precision3,color='green',label='%s               (Auc = %0.3f%%)' % ('PR curve of moldy', pr_auc3))
plt.legend(loc='lower left')
plt.title("PR Curve" ,size = 22)

f_scores = np.linspace(0.4, 0.8, num=3)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('F$_1$={0:0.1f}'.format(f_score), xy=(0.8, y[45] + 0.02)) 
    
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.grid()
plt.xlabel('Recall',size =20)
plt.ylabel('Precision',size =20)
plt.show()
